# %%
import numpy as np

loss_file = "/scratch/gpfs/sbfisher/TrainingResults/AntennaInverseLoss.npy"
grad_file = "/scratch/gpfs/sbfisher/TrainingResults/AntennaInverseGrads.npy"

loss = np.load(loss_file)
grads = np.load(grad_file)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[14], line 7
#       4 grad_file = "/scratch/gpfs/sbfisher/TrainingResults/AntennaInverseGrads.npy"
#       6 loss = np.load(loss_file)
# ----> 7 grads = np.load(grad_file)
#
# File ~/.conda/envs/CadenceEnv/lib/python3.12/site-packages/numpy/lib/npyio.py:427, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     425     own_fid = False
#     426 else:
# --> 427     fid = stack.enter_context(open(os_fspath(file), "rb"))
#     428     own_fid = True
#     430 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: '/scratch/gpfs/sbfisher/TrainingResults/AntennaInverseGrads.npy'

# %%
print(loss.shape)
# Ls loss, then Ld, then Lb
# Out:
# (1, 6, 3)

# %%
import matplotlib.pyplot as plt

plt.plot(range(loss.shape[1]), loss[0,:,0])
plt.title("Ls loss")
plt.xlabel("epoch")
plt.ylabel("MSE loss S vs S'")
# Out:
# Text(0, 0.5, "MSE loss S vs S'")

# %%
plt.plot(range(loss.shape[1]), loss[0,:,1])
plt.title("Ld loss")
plt.xlabel("epoch")
plt.ylabel("MSE loss D vs D'")
# Out:
# Text(0, 0.5, "MSE loss D vs D'")

# %%
plt.plot(range(loss.shape[1]), loss[0,:,2])
plt.title("Binary loss")
plt.xlabel("epoch")
plt.ylabel("Binary loss")
# Out:
# Text(0, 0.5, 'Binary loss')
